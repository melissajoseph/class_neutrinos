# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
#from classy import Class

# %%
Geff2_m_23 = np.loadtxt("output/Geff2_m-23_cl_lensed.dat", unpack=True)
Geff2_m_06 = np.loadtxt("output/Geff2_m-06_cl_lensed.dat", unpack=True)
lcdm = np.loadtxt("output/lcdm_m-06_cl_lensed.dat", unpack=True)

# %%
plt.rcParams["figure.figsize"] = [15.0,5.0]
plt.plot(lcdm[0],(Geff2_m_06[1]-lcdm[1])/lcdm[1])
plt.plot(lcdm[0],(Geff2_m_23[1]-lcdm[1])/lcdm[1], linestyle='--')
